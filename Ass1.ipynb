# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('insurance.csv')

# %%
df
# Out:
#      age\tsex\tbmi\tchildren\tsmoker\tregion\tcharges
# 0      19\tfemale\t27.9\t0\tyes\tsouthwest\t16884.924
# 1        18\tmale\t33.77\t1\tno\tsoutheast\t1725.5523
# 2          28\tmale\t33.0\t3\tno\tsoutheast\t4449.462
# 3     33\tmale\t22.705\t0\tno\tnorthwest\t21984.47061
# 4        32\tmale\t28.88\t0\tno\tnorthwest\t3866.8552
# 5      31\tfemale\t25.74\t0\tno\tsoutheast\t3756.6216
# 6      46\tfemale\t33.44\t1\tno\tsoutheast\t8240.5896
# 7      37\tfemale\t27.74\t3\tno\tnorthwest\t7281.5056
# 8       37\tmale\t29.83\t2\tno\tnortheast\t6406.4107.
# 9    60\tfemale\t25.84\t0\tno\tnorthwest\t28923.13692
# 10       25\tmale\t26.22\t0\tno\tnortheast\t2721.3208
# 11   62\tfemale\t26.29\t0\tyes\tsoutheast\t27808.7251
# 12         23\tmale\t34.4\t0\tno\tsouthwest\t1826.843
# 13    56\tfemale\t39.82\t0\tno\tsoutheast\t11090.7178
# 14     27\tmale\t42.13\t0\tyes\tsoutheast\t39611.7577
# 15         19\tmale\t24.6\t1\tno\tsouthwest\t1837.237
# 16    52\tfemale\t30.78\t1\tno\tnortheast\t10797.3362
# 17     23\tmale\t23.845\t0\tno\tnortheast\t2395.17155
# 18        56\tmale\t40.3\t0\tno\tsouthwest\t10602.385
# 19       30\tmale\t35.3\t0\tyes\tsouthwest\t36837.467
# 20  60\tfemale\t36.005\t0\tno\tnortheast\t13228.84695
# 21       30\tfemale\t32.4\t1\tno\tsouthwest\t4149.736
# 22         18\tmale\t34.1\t0\tno\tsoutheast\t1137.011
# 23   34\tfemale\t31.92\t1\tyes\tnortheast\t37701.8768
# 24     37\tmale\t28.025\t2\tno\tnorthwest\t6203.90175
# 25    59\tfemale\t27.72\t3\tno\tsoutheast\t14001.1338
# 26  63\tfemale\t23.085\t0\tno\tnortheast\t14451.83515
# 27  55\tfemale\t32.775\t2\tno\tnorthwest\t12268.63225
# 28     23\tmale\t17.385\t1\tno\tnorthwest\t2775.19215
# 29           31\tmale\t36.3\t2\tyes\tsouthwest\t38711
# 30       22\tmale\t35.6\t0\tyes\tsouthwest\t35585.576
# 31   18\tfemale\t26.315\t0\tno\tnortheast\t2198.18985
# 32       19\tfemale\t28.6\t5\tno\tsouthwest\t4687.797
# 33      63\tmale\t28.31\t0\tno\tnorthwest\t13770.0979
# 34     28\tmale\t36.4\t1\tyes\tsouthwest\t51194.55914
# 35     19\tmale\t20.425\t0\tno\tnorthwest\t1625.43375
# 36  62\tfemale\t32.965\t3\tno\tnorthwest\t15612.19335
# 37           26\tmale\t20.8\t0\tno\tsouthwest\t2302.3
# 38     35\tmale\t36.67\t1\tyes\tnortheast\t39774.2763
# 39       60\tmale\t39.9\t0\tyes\tsouthwest\t48173.361
# 40       24\tfemale\t26.6\t0\tno\tnortheast\t3046.062
# 41     31\tfemale\t36.63\t2\tno\tsoutheast\t4949.7587
# 42       41\tmale\t21.78\t1\tno\tsoutheast\t6272.4772
# 43       37\tfemale\t30.8\t2\tno\tsoutheast\t6313.759
# 44       38\tmale\t37.05\t1\tno\tnortheast\t6079.6715
# 45      55\tmale\t37.3\t0\tno\tsouthwest\t20630.28351
# 46   18\tfemale\t38.665\t2\tno\tnortheast\t3393.35635
# 47     28\tfemale\t34.77\t0\tno\tnorthwest\t3556.9223
# 48    60\tfemale\t24.53\t0\tno\tsoutheast\t12629.8967

# %%
df[['age','sex','bmi','children','smoker','region','charges']] = df['age\tsex\tbmi\tchildren\tsmoker\tregion\tcharges'].str.split('\t',expand = True)

# %%
df
# Out:
#      age\tsex\tbmi\tchildren\tsmoker\tregion\tcharges age     sex     bmi  \
# 0      19\tfemale\t27.9\t0\tyes\tsouthwest\t16884.924  19  female    27.9
# 1        18\tmale\t33.77\t1\tno\tsoutheast\t1725.5523  18    male   33.77
# 2          28\tmale\t33.0\t3\tno\tsoutheast\t4449.462  28    male    33.0
# 3     33\tmale\t22.705\t0\tno\tnorthwest\t21984.47061  33    male  22.705
# 4        32\tmale\t28.88\t0\tno\tnorthwest\t3866.8552  32    male   28.88
# 5      31\tfemale\t25.74\t0\tno\tsoutheast\t3756.6216  31  female   25.74
# 6      46\tfemale\t33.44\t1\tno\tsoutheast\t8240.5896  46  female   33.44
# 7      37\tfemale\t27.74\t3\tno\tnorthwest\t7281.5056  37  female   27.74
# 8       37\tmale\t29.83\t2\tno\tnortheast\t6406.4107.  37    male   29.83
# 9    60\tfemale\t25.84\t0\tno\tnorthwest\t28923.13692  60  female   25.84
# 10       25\tmale\t26.22\t0\tno\tnortheast\t2721.3208  25    male   26.22
# 11   62\tfemale\t26.29\t0\tyes\tsoutheast\t27808.7251  62  female   26.29
# 12         23\tmale\t34.4\t0\tno\tsouthwest\t1826.843  23    male    34.4
# 13    56\tfemale\t39.82\t0\tno\tsoutheast\t11090.7178  56  female   39.82
# 14     27\tmale\t42.13\t0\tyes\tsoutheast\t39611.7577  27    male   42.13
# 15         19\tmale\t24.6\t1\tno\tsouthwest\t1837.237  19    male    24.6
# 16    52\tfemale\t30.78\t1\tno\tnortheast\t10797.3362  52  female   30.78
# 17     23\tmale\t23.845\t0\tno\tnortheast\t2395.17155  23    male  23.845
# 18        56\tmale\t40.3\t0\tno\tsouthwest\t10602.385  56    male    40.3
# 19       30\tmale\t35.3\t0\tyes\tsouthwest\t36837.467  30    male    35.3
# 20  60\tfemale\t36.005\t0\tno\tnortheast\t13228.84695  60  female  36.005
# 21       30\tfemale\t32.4\t1\tno\tsouthwest\t4149.736  30  female    32.4
# 22         18\tmale\t34.1\t0\tno\tsoutheast\t1137.011  18    male    34.1
# 23   34\tfemale\t31.92\t1\tyes\tnortheast\t37701.8768  34  female   31.92
# 24     37\tmale\t28.025\t2\tno\tnorthwest\t6203.90175  37    male  28.025
# 25    59\tfemale\t27.72\t3\tno\tsoutheast\t14001.1338  59  female   27.72
# 26  63\tfemale\t23.085\t0\tno\tnortheast\t14451.83515  63  female  23.085
# 27  55\tfemale\t32.775\t2\tno\tnorthwest\t12268.63225  55  female  32.775
# 28     23\tmale\t17.385\t1\tno\tnorthwest\t2775.19215  23    male  17.385
# 29           31\tmale\t36.3\t2\tyes\tsouthwest\t38711  31    male    36.3
# 30       22\tmale\t35.6\t0\tyes\tsouthwest\t35585.576  22    male    35.6
# 31   18\tfemale\t26.315\t0\tno\tnortheast\t2198.18985  18  female  26.315
# 32       19\tfemale\t28.6\t5\tno\tsouthwest\t4687.797  19  female    28.6
# 33      63\tmale\t28.31\t0\tno\tnorthwest\t13770.0979  63    male   28.31
# 34     28\tmale\t36.4\t1\tyes\tsouthwest\t51194.55914  28    male    36.4
# 35     19\tmale\t20.425\t0\tno\tnorthwest\t1625.43375  19    male  20.425
# 36  62\tfemale\t32.965\t3\tno\tnorthwest\t15612.19335  62  female  32.965
# 37           26\tmale\t20.8\t0\tno\tsouthwest\t2302.3  26    male    20.8
# 38     35\tmale\t36.67\t1\tyes\tnortheast\t39774.2763  35    male   36.67
# 39       60\tmale\t39.9\t0\tyes\tsouthwest\t48173.361  60    male    39.9
# 40       24\tfemale\t26.6\t0\tno\tnortheast\t3046.062  24  female    26.6
# 41     31\tfemale\t36.63\t2\tno\tsoutheast\t4949.7587  31  female   36.63
# 42       41\tmale\t21.78\t1\tno\tsoutheast\t6272.4772  41    male   21.78
# 43       37\tfemale\t30.8\t2\tno\tsoutheast\t6313.759  37  female    30.8
# 44       38\tmale\t37.05\t1\tno\tnortheast\t6079.6715  38    male   37.05
# 45      55\tmale\t37.3\t0\tno\tsouthwest\t20630.28351  55    male    37.3
# 46   18\tfemale\t38.665\t2\tno\tnortheast\t3393.35635  18  female  38.665
# 47     28\tfemale\t34.77\t0\tno\tnorthwest\t3556.9223  28  female   34.77
# 48    60\tfemale\t24.53\t0\tno\tsoutheast\t12629.8967  60  female   24.53
#
#    children smoker     region      charges
# 0         0    yes  southwest    16884.924
# 1         1     no  southeast    1725.5523
# 2         3     no  southeast     4449.462
# 3         0     no  northwest  21984.47061
# 4         0     no  northwest    3866.8552
# 5         0     no  southeast    3756.6216
# 6         1     no  southeast    8240.5896
# 7         3     no  northwest    7281.5056
# 8         2     no  northeast   6406.4107.
# 9         0     no  northwest  28923.13692
# 10        0     no  northeast    2721.3208
# 11        0    yes  southeast   27808.7251
# 12        0     no  southwest     1826.843
# 13        0     no  southeast   11090.7178
# 14        0    yes  southeast   39611.7577
# 15        1     no  southwest     1837.237
# 16        1     no  northeast   10797.3362
# 17        0     no  northeast   2395.17155
# 18        0     no  southwest    10602.385
# 19        0    yes  southwest    36837.467
# 20        0     no  northeast  13228.84695
# 21        1     no  southwest     4149.736
# 22        0     no  southeast     1137.011
# 23        1    yes  northeast   37701.8768
# 24        2     no  northwest   6203.90175
# 25        3     no  southeast   14001.1338
# 26        0     no  northeast  14451.83515
# 27        2     no  northwest  12268.63225
# 28        1     no  northwest   2775.19215
# 29        2    yes  southwest        38711
# 30        0    yes  southwest    35585.576
# 31        0     no  northeast   2198.18985
# 32        5     no  southwest     4687.797
# 33        0     no  northwest   13770.0979
# 34        1    yes  southwest  51194.55914
# 35        0     no  northwest   1625.43375
# 36        3     no  northwest  15612.19335
# 37        0     no  southwest       2302.3
# 38        1    yes  northeast   39774.2763
# 39        0    yes  southwest    48173.361
# 40        0     no  northeast     3046.062
# 41        2     no  southeast    4949.7587
# 42        1     no  southeast    6272.4772
# 43        2     no  southeast     6313.759
# 44        1     no  northeast    6079.6715
# 45        0     no  southwest  20630.28351
# 46        2     no  northeast   3393.35635
# 47        0     no  northwest    3556.9223
# 48        0     no  southeast   12629.8967

# %%
df = df.drop('age\tsex\tbmi\tchildren\tsmoker\tregion\tcharges', axis = 1 )

# %%
df
# Out:
#    age     sex     bmi children smoker     region      charges
# 0   19  female    27.9        0    yes  southwest    16884.924
# 1   18    male   33.77        1     no  southeast    1725.5523
# 2   28    male    33.0        3     no  southeast     4449.462
# 3   33    male  22.705        0     no  northwest  21984.47061
# 4   32    male   28.88        0     no  northwest    3866.8552
# 5   31  female   25.74        0     no  southeast    3756.6216
# 6   46  female   33.44        1     no  southeast    8240.5896
# 7   37  female   27.74        3     no  northwest    7281.5056
# 8   37    male   29.83        2     no  northeast   6406.4107.
# 9   60  female   25.84        0     no  northwest  28923.13692
# 10  25    male   26.22        0     no  northeast    2721.3208
# 11  62  female   26.29        0    yes  southeast   27808.7251
# 12  23    male    34.4        0     no  southwest     1826.843
# 13  56  female   39.82        0     no  southeast   11090.7178
# 14  27    male   42.13        0    yes  southeast   39611.7577
# 15  19    male    24.6        1     no  southwest     1837.237
# 16  52  female   30.78        1     no  northeast   10797.3362
# 17  23    male  23.845        0     no  northeast   2395.17155
# 18  56    male    40.3        0     no  southwest    10602.385
# 19  30    male    35.3        0    yes  southwest    36837.467
# 20  60  female  36.005        0     no  northeast  13228.84695
# 21  30  female    32.4        1     no  southwest     4149.736
# 22  18    male    34.1        0     no  southeast     1137.011
# 23  34  female   31.92        1    yes  northeast   37701.8768
# 24  37    male  28.025        2     no  northwest   6203.90175
# 25  59  female   27.72        3     no  southeast   14001.1338
# 26  63  female  23.085        0     no  northeast  14451.83515
# 27  55  female  32.775        2     no  northwest  12268.63225
# 28  23    male  17.385        1     no  northwest   2775.19215
# 29  31    male    36.3        2    yes  southwest        38711
# 30  22    male    35.6        0    yes  southwest    35585.576
# 31  18  female  26.315        0     no  northeast   2198.18985
# 32  19  female    28.6        5     no  southwest     4687.797
# 33  63    male   28.31        0     no  northwest   13770.0979
# 34  28    male    36.4        1    yes  southwest  51194.55914
# 35  19    male  20.425        0     no  northwest   1625.43375
# 36  62  female  32.965        3     no  northwest  15612.19335
# 37  26    male    20.8        0     no  southwest       2302.3
# 38  35    male   36.67        1    yes  northeast   39774.2763
# 39  60    male    39.9        0    yes  southwest    48173.361
# 40  24  female    26.6        0     no  northeast     3046.062
# 41  31  female   36.63        2     no  southeast    4949.7587
# 42  41    male   21.78        1     no  southeast    6272.4772
# 43  37  female    30.8        2     no  southeast     6313.759
# 44  38    male   37.05        1     no  northeast    6079.6715
# 45  55    male    37.3        0     no  southwest  20630.28351
# 46  18  female  38.665        2     no  northeast   3393.35635
# 47  28  female   34.77        0     no  northwest    3556.9223
# 48  60  female   24.53        0     no  southeast   12629.8967

# %%
df.head()
# Out:
#   age     sex     bmi children smoker     region      charges
# 0  19  female    27.9        0    yes  southwest    16884.924
# 1  18    male   33.77        1     no  southeast    1725.5523
# 2  28    male    33.0        3     no  southeast     4449.462
# 3  33    male  22.705        0     no  northwest  21984.47061
# 4  32    male   28.88        0     no  northwest    3866.8552

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       49 non-null     object
#  1   sex       49 non-null     object
#  2   bmi       49 non-null     object
#  3   children  49 non-null     object
#  4   smoker    49 non-null     object
#  5   region    49 non-null     object
#  6   charges   49 non-null     object
# dtypes: object(7)
# memory usage: 2.8+ KB

# %%
df.shape
# Out:
# (49, 7)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.describe()
# Out:
#        age   sex   bmi children smoker     region    charges
# count   49    49    49       49     49         49         49
# unique  26     2    49        5      2          4         49
# top     19  male  27.9        0     no  southwest  16884.924
# freq     4    26     1       26     39         13          1

# %%
list(df.sex.unique())
# Out:
# ['female', 'male']

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df[df.duplicated(keep='first')]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, charges]
# Index: []

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['charges'], kde=True, color='r')  # Adding kde=True for kernel density estimate
plt.title('Charges Distribution', size=18)
plt.xlabel('Charges', size=14)
plt.ylabel('Density', size=14)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df.age)
plt.title('Age Distribution',size=18)
plt.xlabel('Age',size=14)
plt.ylabel('Count',size=14)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(df.bmi,color='y')
plt.title('BMI Distribution',size=18)
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.boxplot(df.charges)
plt.title('Distribution Charges', size = 18)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = 'sex', data = df)
plt.title('Total Number of Male and Female',size=18)
plt.xlabel('Sex',size=14)
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.countplot(df.children)
plt.title('Children Distribution', size = 18)
plt.xlabel('Children', size = 14)
plt.ylabel('Count' , size = 14)
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.countplot(df.smoker)
plt.title('Smoker Distribution',size=18)
plt.xlabel('Smoker',size=14)
plt.ylabel('Count',size=14)
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.countplot(df.region,palette='Blues')
plt.title('Region Distribution',size=18)
plt.xlabel('Region',size=14)
plt.ylabel('Count',size=14)
plt.show()
# Out:
# C:\Users\ML\AppData\Local\Temp\ipykernel_10524\3039026012.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df.region,palette='Blues')

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x='age',y='charges',color='r',data=df)
plt.title('Age vs Charges',size=18)
plt.xlabel('Age',size=14)
plt.ylabel('Charges',size=14)
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.set_style('darkgrid')
sns.boxplot(x='smoker',y='charges',data=df)
plt.title('Smoker vs Charges',size=18);

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
columns_to_convert = ['age', 'bmi', 'children', 'charges'] 

df[columns_to_convert] = df[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       49 non-null     int64
#  1   sex       49 non-null     object
#  2   bmi       49 non-null     float64
#  3   children  49 non-null     int64
#  4   smoker    49 non-null     object
#  5   region    49 non-null     object
#  6   charges   48 non-null     float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 2.8+ KB

# %%
sns.pairplot(df, 
                 markers="+",
                 diag_kind="kde",
                 kind='reg',
                 plot_kws={'line_kws':{'color':'#aec6cf'}, 
                           'scatter_kws': {'alpha': 0.7, 
                                           'color': 'red'}},
                 corner=True)
